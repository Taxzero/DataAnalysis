# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import missingno as msno
import matplotlib as mpl
import matplotlib
import platform
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
# %matplotlib inline

# %%
df = pd.read_csv('D:/programming/쌀품종정보2.csv')
df.head()
# Out:
#         품종   제현율   도정율  백미 완전립 비율  장폭비 심복백(0~9) 알카리붕괴도(1~7)  단백질 함량(%)  \
# 0      미소찬   NaN   NaN        NaN  NaN      NaN         NaN        NaN
# 1  JJ621MR  82.9  74.4        NaN  NaN      NaN         NaN        6.5
# 2      월하미  83.6  74.1       67.8  3.2      0/2           7        6.8
# 3      참동진   NaN  75.1        NaN  NaN      NaN         NaN        5.7
# 4       진평   NaN   NaN        NaN  NaN      NaN         NaN        5.6
#
#    아밀로스함량(%) 밥   맛z)관능검정(-3∼+3 투명도1~9
# 0        NaN               NaN    NaN
# 1       19.7               NaN    NaN
# 2       23.3               NaN      1
# 3       18.7              0.11    NaN
# 4       18.8              0.42    NaN

# %%
print(platform.system()) # 플랫폼 확인
# Window
if platform.system() == 'Windows':
    matplotlib.rc('font', family='Malgun Gothic')
elif platform.system() == 'Darwin': # Mac
    matplotlib.rc('font', family='AppleGothic')
else: #linux
    matplotlib.rc('font', family='NanumGothic')
# 그래프에 마이너스 표시가 되도록 변경
matplotlib.rcParams['axes.unicode_minus'] = False
df.index = df
# Out:
# Windows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 281 entries, ('미소찬', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan) to ('참드림', nan, nan, nan, nan, nan, nan, 5.4, 19.5, nan, nan)
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   품종                 281 non-null    object
#  1   제현율                166 non-null    float64
#  2   도정율                218 non-null    object
#  3   백미 완전립 비율          188 non-null    float64
#  4   장폭비                194 non-null    float64
#  5   심복백(0~9)           241 non-null    object
#  6   알카리붕괴도(1~7)        148 non-null    object
#  7   단백질 함량(%)          167 non-null    float64
#  8   아밀로스함량(%)          257 non-null    float64
#  9   밥   맛z)관능검정(-3∼+3  95 non-null     object
#  10  투명도1~9             176 non-null    object
# dtypes: float64(5), object(6)
# memory usage: 26.3+ KB

# %%
dfnull= df.isnull().sum()
dfnull
# Out:
# 품종                     0
# 제현율                  115
# 도정율                   63
# 백미 완전립 비율             93
# 장폭비                   87
# 심복백(0~9)              40
# 알카리붕괴도(1~7)          133
# 단백질 함량(%)            114
# 아밀로스함량(%)             24
# 밥   맛z)관능검정(-3∼+3    186
# 투명도1~9               105
# dtype: int64

# %%
dfnull.plot(kind='bar', stacked=True, figsize=(10,8))
plt.legend(loc='lower left',bbox_to_anchor=(0.8,0.1))
plt.show()

# %%
df.describe()
# Out:
#               제현율   백미 완전립 비율         장폭비   단백질 함량(%)   아밀로스함량(%)
# count  166.000000  188.000000  194.000000  167.000000  257.000000
# mean    82.673494   91.008404    1.835928    6.453293   18.816732
# std      2.283224    8.712256    0.218709    0.652012    1.944763
# min     66.400000   50.900000    1.590000    5.000000    0.600000
# 25%     82.000000   88.950000    1.740000    6.000000   18.300000
# 50%     82.800000   93.900000    1.790000    6.400000   18.900000
# 75%     83.600000   96.025000    1.860000    6.900000   19.500000
# max     93.400000   98.900000    3.370000    8.500000   27.300000

# %%
df_mean = df.mean()
print(df_mean)
# Out:
# 제현율          82.673494
# 백미 완전립 비율    91.008404
# 장폭비           1.835928
# 단백질 함량(%)     6.453293
# 아밀로스함량(%)    18.816732
# dtype: float64

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
df1= df.dropna(subset=['단백질 함량(%)','아밀로스함량(%)'])
df1
# Out:
#           품종   제현율   도정율  백미 완전립 비율   장폭비 심복백(0~9) 알카리붕괴도(1~7)  단백질 함량(%)  \
# 1    JJ621MR  82.9  74.4        NaN   NaN      NaN         NaN        6.5
# 2        월하미  83.6  74.1       67.8  3.20      0/2           7        6.8
# 3        참동진   NaN  75.1        NaN   NaN      NaN         NaN        5.7
# 4         진평   NaN   NaN        NaN   NaN      NaN         NaN        5.6
# 5        해맑은  81.8    73       93.4  1.88      0/1         6.7        5.3
# ..       ...   ...   ...        ...   ...      ...         ...        ...
# 276      백진주   NaN   NaN        NaN   NaN      NaN         NaN        5.6
# 277       진상   NaN   NaN        NaN   NaN      NaN         NaN        6.8
# 278    골드퀸3호   NaN   NaN        NaN   NaN      NaN         NaN        6.0
# 279      밀키퀸   NaN   NaN        NaN   NaN      NaN         NaN        6.9
# 280      참드림   NaN   NaN        NaN   NaN      NaN         NaN        5.4
#
#      아밀로스함량(%) 밥   맛z)관능검정(-3∼+3 투명도1~9
# ...

# %%
msno.bar(df1)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df1)
# Out:
# <AxesSubplot:>

# %%
df2= df.dropna()
df2
# Out:
#             품종   제현율       도정율  백미 완전립 비율   장폭비 심복백(0~9) 알카리붕괴도(1~7)  \
# 6           조영  82.8      72.2       59.9  1.90      0/1           6
# 10         이루미  82.7      74.5       77.8  1.81      0/1         6.8
# 11         알찬미  82.4      75.8       96.2  1.77      0/0         6.4
# 12          안평  83.9      76.5       87.9  1.81      1/0         6.7
# 16   아이에스592비비  81.5      72.6       82.5  1.79      0/1           6
# 19   엠와이298비비(  82.8      74.4       87.6  1.75      0/1         6.6
# 20   씨더블유92-엠알  81.5      71.4       75.6  1.76      0/1         6.1
# 21   엠와이299비케이  80.3      72.4       88.8  2.04      0/1         6.5
# 22          단평  83.1      75.9       94.6  1.80      0/1         6.7
# 24      중모1045  83.2      76.1       93.3  1.69      0/0         6.4
# 25          조일  81.7        74       79.5  1.88      0/1           6
# 28        삼광1호  82.2      74.8       86.8  1.77      0/0         6.2
# 30          진한  84.0      77.1       94.6  1.81      0/0         6.8
# ...

# %%
plt.figure(figsize=(100,50))
plt.scatter(df['제현율'],df['품종'], label='제현율')

# %%
plt.figure(figsize=(100,50))
plt.bar(df, '품종')
plt.xticks(df, '제현율')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-a62ecf84df6c> in <module>
#       1 plt.figure(figsize=(100,50))
# ----> 2 plt.bar(df, '품종')
#       3 plt.xticks(df, '제현율')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2649         x, height, width=0.8, bottom=None, *, align='center',
#    2650         data=None, **kwargs):
# -> 2651     return gca().bar(
#    2652         x, height, width=width, bottom=bottom, align=align,
#    2653         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# ...
