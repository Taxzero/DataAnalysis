# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import missingno as msno
import matplotlib as mpl
import matplotlib
import platform
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
# %matplotlib inline

# %%
df1 = pd.read_excel('D:/programming/1_1.xlsx')
df1.head()
# Out:
#        품종   제현율   도정율  백미 완전립 비율   장폭비 심복백(0~9)  알카리붕괴도(1~7)  단백질 함량(%)  \
# 0      신백  82.3  70.1       79.2  1.75      0/0          6.7        8.5
# 1  중모1004  66.4  48.1       50.9  1.74      0/0          6.4        8.3
# 2  중모1043  80.3  72.8       85.0  1.87      0/1          6.5        8.2
# 3   한아름2호  82.0  72.6       58.6  2.16      2/0          6.0        8.2
# 4     새계화   NaN  75.1       94.1   NaN      0/1          5.9        7.8
#
#    아밀로스함량(%)  밥맛관능검정-3∼+3  투명도1~9
# 0       17.8        -0.16     NaN
# 1       15.1          NaN     NaN
# 2       19.3          NaN     1.0
# 3       17.5        -0.90     1.0
# 4       19.3          NaN     NaN

# %%
df2 = pd.read_excel('D:/programming/2_2.xlsx')
df2.head()
# Out:
#     품종  제현율   도정율  백미 완전립 비율   장폭비 심복백(0~9)  알카리붕괴도(1~7)  단백질 함량(%)  \
# 0  흑진미  NaN   NaN        NaN  2.25      NaN          6.3       7.20
# 1   조운  NaN  74.7       89.4  1.87      0/0          NaN       7.20
# 2   만종  NaN  74.8       97.8  1.86      0/0          NaN       7.20
# 3   서명  NaN  76.9       97.2  1.77      0/0          NaN       7.20
# 4   호반  NaN  76.5       94.7  1.67      0/1          NaN       7.15
#
#    아밀로스함량(%)  밥맛관능검정-3∼+3  투명도1~9
# 0       19.2          NaN     NaN
# 1       17.8          NaN     NaN
# 2       18.7          NaN     NaN
# 3       19.3          NaN     NaN
# 4       17.5          NaN     NaN

# %%
df3 = pd.read_excel('D:/programming/3_3.xlsx')
df3.head()
# Out:
#     품종   제현율   도정율  백미 완전립 비율   장폭비 심복백(0~9)  알카리붕괴도(1~7)  단백질 함량(%)  \
# 0  밀키퀸   NaN   NaN        NaN   NaN      NaN          NaN        6.9
# 1  월하미  83.6  74.1       67.8  3.20      0/2          7.0        6.8
# 2   조품  82.5  75.9       94.8  1.82  01월 01일          6.1        6.8
# 3   청남   NaN  76.1       98.2  1.82      0/0          NaN        6.8
# 4  온누리  83.4  75.6       87.8  1.59      0/0          6.2        6.8
#
#    아밀로스함량(%)  밥맛관능검정-3∼+3  투명도1~9
# 0       14.7          NaN     NaN
# 1       23.3          NaN     1.0
# 2       18.6         0.00     1.0
# 3       19.3          NaN     NaN
# 4       18.6         0.41     1.0

# %%
df4 = pd.read_excel('D:/programming/4_4.xlsx')
df4.head()
# Out:
#      품종   제현율   도정율  백미 완전립 비율   장폭비 심복백(0~9)  알카리붕괴도(1~7)  단백질 함량(%)  \
# 0    수안  83.3  74.0       87.1  1.77      0/0          5.6        6.5
# 1   조아미   NaN  76.4       88.2  1.83      0/0          NaN        6.5
# 2    한들   NaN  74.5       93.0  1.82      0/0          NaN        6.5
# 3  해찬물결  82.4  74.8       96.3  1.77      0/0          6.2        6.5
# 4  오대1호  82.8  75.6       93.5  2.20      0/1          6.1        6.5
#
#    아밀로스함량(%)  밥맛관능검정-3∼+3  투명도1~9
# 0       19.5        -0.07     1.0
# 1       17.1          NaN     NaN
# 2       19.2          NaN     NaN
# 3       18.9          NaN     1.0
# 4       19.5          NaN     1.0

# %%
df5 = pd.read_excel('D:/programming/5_5.xlsx')
df5.head()
# Out:
#           품종   제현율   도정율  백미 완전립 비율   장폭비 심복백(0~9)  알카리붕괴도(1~7)  단백질 함량(%)  \
# 0         일품  82.6  77.2        NaN   NaN      0/1          5.9        6.4
# 1  케이지에이치알1호  82.4  73.8       54.8  3.37      0/1          7.0        6.3
# 2        이루미  82.7  74.5       77.8  1.81      0/1          6.8        6.3
# 3         안평  83.9  76.5       87.9  1.81      1/0          6.7        6.3
# 4         새신  83.2  76.2       97.3  1.85      0/0          6.6        6.3
#
#    아밀로스함량(%)  밥맛관능검정-3∼+3  투명도1~9
# 0       18.9          NaN     2.0
# 1       22.7          NaN     1.0
# 2       19.6         0.40     1.7
# 3       19.5         0.43     1.0
# 4       20.9         0.04     1.0

# %%
df6 = pd.read_excel('D:/programming/6_6.xlsx')
df6.head()
# Out:
#       품종   제현율   도정율  백미 완전립 비율   장폭비 심복백(0~9)  알카리붕괴도(1~7)  단백질 함량(%)  \
# 0     진백   NaN  74.8       95.9  1.76      0/0          NaN        6.2
# 1   황금누리  82.4  74.4       97.1   NaN      0/0          6.3        6.2
# 2   주안1호  81.1  73.9       91.9  1.66      0/0          6.6        6.2
# 3  신운봉1호  82.4  74.1       85.6  1.77      0/1          NaN        6.2
# 4     만나  82.6  75.2       92.5   NaN      0/0          6.3        6.2
#
#    아밀로스함량(%)  밥맛관능검정-3∼+3  투명도1~9
# 0       18.8          NaN     NaN
# 1       18.9         0.30     1.0
# 2       18.8          NaN     1.0
# 3       19.2         0.25     1.0
# 4       19.0         0.37     1.0

# %%
df7 = pd.read_excel('D:/programming/7_7.xlsx')
df7.head()
# Out:
#      품종   제현율   도정율  백미 완전립 비율   장폭비 심복백(0~9)  알카리붕괴도(1~7)  단백질 함량(%)  \
# 0    영보  84.6  77.7       94.9  1.80      0/0          6.7        6.0
# 1    진옥  85.0  76.8       78.4  1.79      0/0          6.7        6.0
# 2  영호진미   NaN  75.4       95.3  1.75      0/0          NaN        6.0
# 3  하이아미   NaN  74.1       93.5  1.87      0/0          NaN        6.0
# 4  해오르미   NaN  76.6       94.3  1.78      0/0          NaN        6.0
#
#    아밀로스함량(%)  밥맛관능검정-3∼+3  투명도1~9
# 0       20.2         0.26     1.0
# 1       20.0         0.05     1.0
# 2       19.0          NaN     NaN
# 3       18.2          NaN     NaN
# 4       18.0          NaN     NaN

# %%
df8 = pd.read_excel('D:/programming/8_8.xlsx')
df8.head()
# Out:
#        품종   제현율   도정율  백미 완전립 비율   장폭비 심복백(0~9)  알카리붕괴도(1~7)  단백질 함량(%)  \
# 0  중모1041  83.0  76.1       96.9  1.74      0/1          6.5        5.7
# 1      강찬  82.4  74.3       93.5  1.72      0/0          6.6        5.7
# 2      다청   NaN  75.7       94.4  1.73      0/1          NaN        5.7
# 3    황금노들   NaN  75.6       90.0  1.69      0/0          NaN        5.7
# 4      삼광  83.0  76.5       94.5  1.72      1/0          5.8        5.7
#
#    아밀로스함량(%) 밥맛관능검정-3∼+3  투명도1~9
# 0       20.9        0.09     1.0
# 1       20.2        0.14     1.0
# 2       18.8         NaN     NaN
# 3       18.6         NaN     NaN
# 4       18.3         0.3     1.0

# %%
print(platform.system()) # 플랫폼 확인
# Window
if platform.system() == 'Windows':
    matplotlib.rc('font', family='Malgun Gothic')
elif platform.system() == 'Darwin': # Mac
    matplotlib.rc('font', family='AppleGothic')
else: #linux
    matplotlib.rc('font', family='NanumGothic')
# 그래프에 마이너스 표시가 되도록 변경
matplotlib.rcParams['axes.unicode_minus'] = False
df.index = df
# Out:
# Windows
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-678dcff5dbd9> in <module>
#       9 # 그래프에 마이너스 표시가 되도록 변경
#      10 matplotlib.rcParams['axes.unicode_minus'] = False
# ---> 11 df.index = df
#
# NameError: name 'df' is not defined

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   품종           20 non-null     object
#  1   제현율          13 non-null     float64
#  2   도정율          19 non-null     float64
#  3   백미 완전립 비율    16 non-null     float64
#  4   장폭비          14 non-null     float64
#  5   심복백(0~9)     18 non-null     object
#  6   알카리붕괴도(1~7)  16 non-null     float64
#  7   단백질 함량(%)    20 non-null     float64
#  8   아밀로스함량(%)    20 non-null     float64
#  9   밥맛관능검정-3∼+3  10 non-null     float64
#  10  투명도1~9       12 non-null     float64
# dtypes: float64(9), object(2)
# memory usage: 1.8+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   품종           20 non-null     object
#  1   제현율          12 non-null     float64
#  2   도정율          19 non-null     float64
#  3   백미 완전립 비율    17 non-null     float64
#  4   장폭비          16 non-null     float64
#  5   심복백(0~9)     18 non-null     object
#  6   알카리붕괴도(1~7)  12 non-null     float64
#  7   단백질 함량(%)    20 non-null     float64
#  8   아밀로스함량(%)    20 non-null     float64
#  9   밥맛관능검정-3∼+3  8 non-null      float64
#  10  투명도1~9       12 non-null     float64
# dtypes: float64(9), object(2)
# memory usage: 1.8+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   품종           20 non-null     object
#  1   제현율          12 non-null     float64
#  2   도정율          14 non-null     float64
#  3   백미 완전립 비율    13 non-null     float64
#  4   장폭비          15 non-null     float64
#  5   심복백(0~9)     16 non-null     object
#  6   알카리붕괴도(1~7)  11 non-null     float64
#  7   단백질 함량(%)    20 non-null     float64
#  8   아밀로스함량(%)    20 non-null     float64
#  9   밥맛관능검정-3∼+3  10 non-null     float64
#  10  투명도1~9       12 non-null     float64
# dtypes: float64(9), object(2)
# memory usage: 1.8+ KB

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   품종           20 non-null     object
#  1   제현율          12 non-null     float64
#  2   도정율          20 non-null     float64
#  3   백미 완전립 비율    20 non-null     float64
#  4   장폭비          18 non-null     float64
#  5   심복백(0~9)     20 non-null     object
#  6   알카리붕괴도(1~7)  12 non-null     float64
#  7   단백질 함량(%)    20 non-null     float64
#  8   아밀로스함량(%)    20 non-null     float64
#  9   밥맛관능검정-3∼+3  9 non-null      float64
#  10  투명도1~9       13 non-null     float64
# dtypes: float64(9), object(2)
# memory usage: 1.8+ KB

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   품종           20 non-null     object
#  1   제현율          16 non-null     float64
#  2   도정율          20 non-null     object
#  3   백미 완전립 비율    18 non-null     float64
#  4   장폭비          18 non-null     float64
#  5   심복백(0~9)     20 non-null     object
#  6   알카리붕괴도(1~7)  16 non-null     float64
#  7   단백질 함량(%)    20 non-null     float64
#  8   아밀로스함량(%)    20 non-null     float64
#  9   밥맛관능검정-3∼+3  12 non-null     float64
#  10  투명도1~9       16 non-null     float64
# dtypes: float64(8), object(3)
# memory usage: 1.8+ KB

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   품종           20 non-null     object
#  1   제현율          13 non-null     float64
#  2   도정율          18 non-null     float64
#  3   백미 완전립 비율    16 non-null     float64
#  4   장폭비          14 non-null     float64
#  5   심복백(0~9)     18 non-null     object
#  6   알카리붕괴도(1~7)  10 non-null     float64
#  7   단백질 함량(%)    20 non-null     float64
#  8   아밀로스함량(%)    20 non-null     float64
#  9   밥맛관능검정-3∼+3  11 non-null     float64
#  10  투명도1~9       14 non-null     float64
# dtypes: float64(9), object(2)
# memory usage: 1.8+ KB

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   품종           20 non-null     object
#  1   제현율          11 non-null     float64
#  2   도정율          17 non-null     float64
#  3   백미 완전립 비율    16 non-null     float64
#  4   장폭비          15 non-null     float64
#  5   심복백(0~9)     16 non-null     object
#  6   알카리붕괴도(1~7)  11 non-null     float64
#  7   단백질 함량(%)    20 non-null     float64
#  8   아밀로스함량(%)    20 non-null     float64
#  9   밥맛관능검정-3∼+3  12 non-null     float64
#  10  투명도1~9       11 non-null     float64
# dtypes: float64(9), object(2)
# memory usage: 1.8+ KB

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   품종           20 non-null     object
#  1   제현율          9 non-null      float64
#  2   도정율          14 non-null     float64
#  3   백미 완전립 비율    13 non-null     float64
#  4   장폭비          16 non-null     float64
#  5   심복백(0~9)     16 non-null     object
#  6   알카리붕괴도(1~7)  9 non-null      float64
#  7   단백질 함량(%)    20 non-null     float64
#  8   아밀로스함량(%)    20 non-null     float64
#  9   밥맛관능검정-3∼+3  12 non-null     object
#  10  투명도1~9       9 non-null      float64
# dtypes: float64(8), object(3)
# memory usage: 1.8+ KB

# %%
dfnull1= df1.isnull().sum()
dfnull1
# Out:
# 품종              0
# 제현율             7
# 도정율             1
# 백미 완전립 비율       4
# 장폭비             6
# 심복백(0~9)        2
# 알카리붕괴도(1~7)     4
# 단백질 함량(%)       0
# 아밀로스함량(%)       0
# 밥맛관능검정-3∼+3    10
# 투명도1~9          8
# dtype: int64

# %%
dfnull2= df2.isnull().sum()
dfnull2
# Out:
# 품종              0
# 제현율             8
# 도정율             1
# 백미 완전립 비율       3
# 장폭비             4
# 심복백(0~9)        2
# 알카리붕괴도(1~7)     8
# 단백질 함량(%)       0
# 아밀로스함량(%)       0
# 밥맛관능검정-3∼+3    12
# 투명도1~9          8
# dtype: int64

# %%
dfnull3= df3.isnull().sum()
dfnull3
# Out:
# 품종              0
# 제현율             8
# 도정율             6
# 백미 완전립 비율       7
# 장폭비             5
# 심복백(0~9)        4
# 알카리붕괴도(1~7)     9
# 단백질 함량(%)       0
# 아밀로스함량(%)       0
# 밥맛관능검정-3∼+3    10
# 투명도1~9          8
# dtype: int64

# %%
dfnull4= df4.isnull().sum()
dfnull4
# Out:
# 품종              0
# 제현율             8
# 도정율             0
# 백미 완전립 비율       0
# 장폭비             2
# 심복백(0~9)        0
# 알카리붕괴도(1~7)     8
# 단백질 함량(%)       0
# 아밀로스함량(%)       0
# 밥맛관능검정-3∼+3    11
# 투명도1~9          7
# dtype: int64

# %%
dfnull5= df5.isnull().sum()
dfnull5
# Out:
# 품종             0
# 제현율            4
# 도정율            0
# 백미 완전립 비율      2
# 장폭비            2
# 심복백(0~9)       0
# 알카리붕괴도(1~7)    4
# 단백질 함량(%)      0
# 아밀로스함량(%)      0
# 밥맛관능검정-3∼+3    8
# 투명도1~9         4
# dtype: int64

# %%
dfnull6= df6.isnull().sum()
dfnull6
# Out:
# 품종              0
# 제현율             7
# 도정율             2
# 백미 완전립 비율       4
# 장폭비             6
# 심복백(0~9)        2
# 알카리붕괴도(1~7)    10
# 단백질 함량(%)       0
# 아밀로스함량(%)       0
# 밥맛관능검정-3∼+3     9
# 투명도1~9          6
# dtype: int64

# %%
dfnull7= df7.isnull().sum()
dfnull7
# Out:
# 품종             0
# 제현율            9
# 도정율            3
# 백미 완전립 비율      4
# 장폭비            5
# 심복백(0~9)       4
# 알카리붕괴도(1~7)    9
# 단백질 함량(%)      0
# 아밀로스함량(%)      0
# 밥맛관능검정-3∼+3    8
# 투명도1~9         9
# dtype: int64

# %%
dfnull8= df8.isnull().sum()
dfnull8
# Out:
# 품종              0
# 제현율            11
# 도정율             6
# 백미 완전립 비율       7
# 장폭비             4
# 심복백(0~9)        4
# 알카리붕괴도(1~7)    11
# 단백질 함량(%)       0
# 아밀로스함량(%)       0
# 밥맛관능검정-3∼+3     8
# 투명도1~9         11
# dtype: int64

# %%
dfnull1.plot(kind='bar', stacked=True, figsize=(10,8))
plt.legend(loc='lower left',bbox_to_anchor=(0.8,0.1))
plt.show()

# %%
dfnull2.plot(kind='bar', stacked=True, figsize=(10,8))
plt.legend(loc='lower left',bbox_to_anchor=(0.8,0.1))
plt.show()

# %%
dfnull3.plot(kind='bar', stacked=True, figsize=(10,8))
plt.legend(loc='lower left',bbox_to_anchor=(0.8,0.1))
plt.show()

# %%
dfnull4.plot(kind='bar', stacked=True, figsize=(10,8))
plt.legend(loc='lower left',bbox_to_anchor=(0.8,0.1))
plt.show()

# %%
dfnull5.plot(kind='bar', stacked=True, figsize=(10,8))
plt.legend(loc='lower left',bbox_to_anchor=(0.8,0.1))
plt.show()

# %%
dfnull6.plot(kind='bar', stacked=True, figsize=(10,8))
plt.legend(loc='lower left',bbox_to_anchor=(0.8,0.1))
plt.show()

# %%
dfnull7.plot(kind='bar', stacked=True, figsize=(10,8))
plt.legend(loc='lower left',bbox_to_anchor=(0.8,0.1))
plt.show()

# %%
dfnull8.plot(kind='bar', stacked=True, figsize=(10,8))
plt.legend(loc='lower left',bbox_to_anchor=(0.8,0.1))
plt.show()

# %%
df1.describe()
# Out:
#              제현율        도정율  백미 완전립 비율        장폭비  알카리붕괴도(1~7)  단백질 함량(%)  \
# count  13.000000  19.000000  16.000000  14.000000    16.000000  20.000000
# mean   81.192308  73.210526  83.137500   1.834286     6.243750   7.635000
# std     4.633836   6.353730  15.459231   0.170191     0.366913   0.380132
# min    66.400000  48.100000  50.900000   1.600000     5.700000   7.300000
# 25%    81.900000  73.050000  83.025000   1.742500     5.875000   7.300000
# 50%    82.300000  74.600000  87.550000   1.820000     6.300000   7.500000
# 75%    83.100000  75.900000  94.225000   1.837500     6.550000   7.725000
# max    85.100000  77.900000  96.500000   2.230000     6.700000   8.500000
#
#        아밀로스함량(%)  밥맛관능검정-3∼+3  투명도1~9
# count  20.000000    10.000000    12.0
# mean   18.635000     0.146000     1.0
# std     1.127771     0.469685     0.0
# min    15.100000    -0.900000     1.0
# 25%    18.125000    -0.070000     1.0
# 50%    18.650000     0.190000     1.0
# ...

# %%
df2.describe()
# Out:
#              제현율        도정율  백미 완전립 비율        장폭비  알카리붕괴도(1~7)  단백질 함량(%)  \
# count  12.000000  19.000000  17.000000  16.000000    12.000000   20.00000
# mean   82.100000  74.336842  90.876471   1.853750     6.041667    7.02300
# std     1.161504   1.810221   9.460545   0.169583     0.867031    0.11788
# min    80.300000  70.800000  59.900000   1.670000     3.500000    6.90000
# 25%    81.150000  73.050000  89.400000   1.735000     6.000000    6.90000
# 50%    82.450000  74.700000  93.500000   1.825000     6.150000    7.00000
# 75%    82.800000  75.550000  96.900000   1.892500     6.500000    7.12000
# max    84.100000  77.400000  98.900000   2.250000     7.000000    7.20000
#
#        아밀로스함량(%)  밥맛관능검정-3∼+3     투명도1~9
# count  20.000000     8.000000  12.000000
# mean   18.855000     0.090000   1.333333
# std     1.936485     0.248193   0.651339
# min    17.500000    -0.430000   1.000000
# 25%    18.000000     0.040000   1.000000
# 50%    18.650000     0.105000   1.000000
# ...

# %%
df3.describe()
# Out:
#              제현율        도정율  백미 완전립 비율        장폭비  알카리붕괴도(1~7)  단백질 함량(%)  \
# count  12.000000  14.000000  13.000000  15.000000    11.000000  20.000000
# mean   82.875000  75.207143  90.153846   1.881333     6.400000   6.675000
# std     1.094719   1.783456   9.645432   0.373590     0.483735   0.111803
# min    79.800000  69.700000  67.800000   1.590000     5.200000   6.500000
# 25%    82.650000  75.200000  87.800000   1.755000     6.250000   6.600000
# 50%    83.050000  75.700000  94.800000   1.820000     6.500000   6.650000
# 75%    83.450000  75.875000  96.500000   1.855000     6.650000   6.800000
# max    84.000000  77.600000  98.200000   3.200000     7.000000   6.900000
#
#        아밀로스함량(%)  밥맛관능검정-3∼+3     투명도1~9
# count  20.000000    10.000000  12.000000
# mean   18.790000     0.104000   1.250000
# std     2.213095     0.299266   0.866025
# min    11.900000    -0.640000   1.000000
# 25%    18.600000     0.010000   1.000000
# 50%    19.100000     0.205000   1.000000
# ...

# %%
df4.describe()
# Out:
#              제현율        도정율  백미 완전립 비율        장폭비  알카리붕괴도(1~7)  단백질 함량(%)  \
# count  12.000000  20.000000  20.000000  18.000000    12.000000  20.000000
# mean   82.708333  75.000000  90.645000   1.820000     6.300000   6.435000
# std     0.953899   1.204815   7.143379   0.157629     0.310425   0.048936
# min    80.700000  72.800000  76.300000   1.650000     5.600000   6.400000
# 25%    82.225000  74.375000  86.325000   1.717500     6.175000   6.400000
# 50%    82.950000  74.950000  93.250000   1.780000     6.300000   6.400000
# 75%    83.325000  75.525000  96.400000   1.837500     6.500000   6.500000
# max    83.900000  78.500000  98.400000   2.230000     6.800000   6.500000
#
#        아밀로스함량(%)  밥맛관능검정-3∼+3  투명도1~9
# count   20.00000     9.000000    13.0
# mean    18.77500     0.042222     1.0
# std      0.73833     0.133302     0.0
# min     17.10000    -0.110000     1.0
# 25%     18.37500    -0.030000     1.0
# 50%     18.80000    -0.010000     1.0
# ...

# %%
df5.describe()
# Out:
#              제현율  백미 완전립 비율        장폭비  알카리붕괴도(1~7)  단백질 함량(%)  아밀로스함량(%)  \
# count  16.000000  18.000000  18.000000    16.000000  20.000000  20.000000
# mean   82.975000  88.850000   1.876111     6.512500   6.280000  19.420000
# std     0.795403  11.025172   0.378451     0.287228   0.052315   1.116197
# min    81.600000  54.800000   1.650000     5.900000   6.200000  17.300000
# 25%    82.550000  87.825000   1.772500     6.350000   6.275000  19.050000
# 50%    83.000000  93.050000   1.795000     6.500000   6.300000  19.400000
# 75%    83.575000  95.400000   1.840000     6.700000   6.300000  19.650000
# max    84.300000  97.300000   3.370000     7.000000   6.400000  22.700000
#
#        밥맛관능검정-3∼+3     투명도1~9
# count    12.000000  16.000000
# mean      0.196667   1.106250
# std       0.204865   0.295452
# min      -0.080000   1.000000
# 25%      -0.012500   1.000000
# 50%       0.315000   1.000000
# 75%       0.355000   1.000000
# max       0.430000   2.000000

# %%
df6.describe()
# Out:
#              제현율        도정율  백미 완전립 비율        장폭비  알카리붕괴도(1~7)  단백질 함량(%)  \
# count  13.000000  18.000000  16.000000  14.000000     10.00000  20.000000
# mean   82.753846  75.283333  92.537500   1.799286      6.41000   6.122000
# std     0.754559   0.972111   4.340334   0.081190      0.25144   0.061524
# min    81.100000  73.900000  84.300000   1.660000      6.10000   6.000000
# 25%    82.400000  74.625000  90.850000   1.752500      6.30000   6.100000
# 50%    82.800000  74.950000  92.550000   1.790000      6.35000   6.100000
# 75%    83.500000  76.050000  96.025000   1.845000      6.47500   6.200000
# max    83.800000  77.300000  98.800000   1.990000      7.00000   6.200000
#
#        아밀로스함량(%)  밥맛관능검정-3∼+3     투명도1~9
# count  20.000000    11.000000  14.000000
# mean   18.050000     0.344545   1.142857
# std     4.143035     0.175805   0.534522
# min     0.600000    -0.050000   1.000000
# 25%    18.775000     0.265000   1.000000
# 50%    18.850000     0.370000   1.000000
# ...

# %%
df7.describe()
# Out:
#              제현율        도정율  백미 완전립 비율        장폭비  알카리붕괴도(1~7)  단백질 함량(%)  \
# count  11.000000  17.000000  16.000000  15.000000    11.000000   20.00000
# mean   83.336364  75.794118  92.856250   1.818667     6.581818    5.90000
# std     1.320812   1.370890   4.896934   0.114134     0.160114    0.11698
# min    80.300000  72.400000  78.400000   1.680000     6.300000    5.70000
# 25%    82.850000  75.100000  91.725000   1.750000     6.450000    5.80000
# 50%    83.600000  76.100000  94.500000   1.790000     6.600000    5.95000
# 75%    84.150000  76.800000  95.225000   1.835000     6.700000    6.00000
# max    85.000000  77.700000  98.800000   2.100000     6.800000    6.00000
#
#        아밀로스함량(%)  밥맛관능검정-3∼+3     투명도1~9
# count  20.000000    12.000000  11.000000
# mean   18.845000     0.205833   1.090909
# std     1.676298     0.096055   0.301511
# min    12.500000     0.050000   1.000000
# 25%    18.625000     0.125000   1.000000
# 50%    19.200000     0.220000   1.000000
# ...

# %%
df8.describe()
# Out:
#              제현율        도정율  백미 완전립 비율        장폭비  알카리붕괴도(1~7)  단백질 함량(%)  \
# count   9.000000  14.000000  13.000000  16.000000     9.000000  20.000000
# mean   82.800000  75.007143  92.507692   1.811875     6.433333   5.505000
# std     0.901388   1.482443   5.519279   0.150830     0.295804   0.193241
# min    81.500000  71.400000  75.600000   1.680000     5.800000   5.000000
# 25%    82.400000  74.400000  91.500000   1.720000     6.400000   5.375000
# 50%    82.900000  75.350000  93.500000   1.760000     6.600000   5.600000
# 75%    83.000000  75.875000  95.400000   1.812500     6.600000   5.625000
# max    84.200000  77.100000  96.900000   2.210000     6.700000   5.700000
#
#        아밀로스함량(%)  투명도1~9
# count  20.000000     9.0
# mean   19.330000     1.0
# std     3.469582     0.0
# min     9.100000     1.0
# 25%    18.375000     1.0
# 50%    18.850000     1.0
# 75%    19.750000     1.0
# max    27.300000     1.0

# %%
msno.matrix(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-3884b1dd1443> in <module>
# ----> 1 msno.matrix(df)
#
# NameError: name 'df' is not defined

# %%
msno.bar(df1)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df2)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df3)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df4)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df5)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df6)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df7)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df8)
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
plt.figure(1)
plt.barh(df1['품종'],df1['제현율'],color='orange')
plt.legend('제현율')

plt.figure(2)
plt.barh(df1['품종'],df1['도정율'],color='wheat')
plt.legend('도정율')

plt.figure(3)
plt.barh(df1['품종'],df1['백미 완전립 비율'],color='darkgoldenrod')
plt.legend('백미 완전립 비율')

plt.figure(4)
plt.barh(df1['품종'],df1['장폭비'],color='goldenrod')
plt.legend('장폭비')

plt.figure(5)
plt.barh(df1['품종'],df1['알카리붕괴도(1~7)'],color='gold')
plt.legend('알카리붕괴도(1~7)')

plt.figure(6)
plt.barh(df1['품종'],df1['단백질 함량(%)'],color='khaki')
plt.legend('단백질 함량(%)')

plt.figure(7)
plt.barh(df1['품종'],df1['아밀로스함량(%)'],color='darkkhaki')
plt.legend('아밀로스함량(%)')

plt.figure(8)
plt.barh(df1['품종'],df1['투명도1~9'],color='yellowgreen')
plt.legend('투명도1~9')

plt.figure(9)
plt.barh(df1['품종'],df1['밥맛관능검정-3∼+3'],color='green')
plt.legend('밥맛관능검정-3∼+3')

# %%
plt.figure(1)
plt.barh(df2['품종'],df2['제현율'],color='orange')
plt.legend('제현율')

plt.figure(2)
plt.barh(df2['품종'],df2['도정율'],color='wheat')
plt.legend('도정율')

plt.figure(3)
plt.barh(df2['품종'],df2['백미 완전립 비율'],color='darkgoldenrod')
plt.legend('백미 완전립 비율')

plt.figure(4)
plt.barh(df2['품종'],df2['장폭비'],color='goldenrod')
plt.legend('장폭비')

plt.figure(5)
plt.barh(df2['품종'],df2['알카리붕괴도(1~7)'],color='gold')
plt.legend('알카리붕괴도(1~7)')

plt.figure(6)
plt.barh(df2['품종'],df2['단백질 함량(%)'],color='khaki')
plt.legend('단백질 함량(%)')

plt.figure(7)
plt.barh(df2['품종'],df2['아밀로스함량(%)'],color='darkkhaki')
plt.legend('아밀로스함량(%)')

plt.figure(8)
plt.barh(df2['품종'],df2['투명도1~9'],color='yellowgreen')
plt.legend('투명도1~9')

plt.figure(9)
plt.barh(df2['품종'],df2['밥맛관능검정-3∼+3'],color='green')
plt.legend('밥맛관능검정-3∼+3')

# %%
plt.figure(1)
plt.barh(df3['품종'],df3['제현율'],color='orange')
plt.legend('제현율')

plt.figure(2)
plt.barh(df3['품종'],df3['도정율'],color='wheat')
plt.legend('도정율')

plt.figure(3)
plt.barh(df3['품종'],df3['백미 완전립 비율'],color='darkgoldenrod')
plt.legend('백미 완전립 비율')

plt.figure(4)
plt.barh(df3['품종'],df3['장폭비'],color='goldenrod')
plt.legend('장폭비')

plt.figure(5)
plt.barh(df3['품종'],df3['알카리붕괴도(1~7)'],color='gold')
plt.legend('알카리붕괴도(1~7)')

plt.figure(6)
plt.barh(df3['품종'],df3['단백질 함량(%)'],color='khaki')
plt.legend('단백질 함량(%)')

plt.figure(7)
plt.barh(df3['품종'],df3['아밀로스함량(%)'],color='darkkhaki')
plt.legend('아밀로스함량(%)')

plt.figure(8)
plt.barh(df3['품종'],df3['투명도1~9'],color='yellowgreen')
plt.legend('투명도1~9')

plt.figure(9)
plt.barh(df3['품종'],df3['밥맛관능검정-3∼+3'],color='green')
plt.legend('밥맛관능검정-3∼+3')

# %%
plt.figure(1)
plt.barh(df4['품종'],df4['제현율'],color='orange')
plt.legend('제현율')

plt.figure(2)
plt.barh(df4['품종'],df4['도정율'],color='wheat')
plt.legend('도정율')

plt.figure(3)
plt.barh(df4['품종'],df4['백미 완전립 비율'],color='darkgoldenrod')
plt.legend('백미 완전립 비율')

plt.figure(4)
plt.barh(df4['품종'],df4['장폭비'],color='goldenrod')
plt.legend('장폭비')

plt.figure(5)
plt.barh(df4['품종'],df4['알카리붕괴도(1~7)'],color='gold')
plt.legend('알카리붕괴도(1~7)')

plt.figure(6)
plt.barh(df4['품종'],df4['단백질 함량(%)'],color='khaki')
plt.legend('단백질 함량(%)')

plt.figure(7)
plt.barh(df4['품종'],df4['아밀로스함량(%)'],color='darkkhaki')
plt.legend('아밀로스함량(%)')

plt.figure(8)
plt.barh(df4['품종'],df4['투명도1~9'],color='yellowgreen')
plt.legend('투명도1~9')

plt.figure(9)
plt.barh(df4['품종'],df4['밥맛관능검정-3∼+3'],color='green')
plt.legend('밥맛관능검정-3∼+3')
